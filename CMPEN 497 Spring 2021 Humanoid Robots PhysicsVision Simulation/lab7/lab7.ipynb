# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
prox_dist_pairs = [(0, 1), (2, 3),
                   (4, 5), (5, 6), (6, 7),
                   (8, 9), (9, 10), (10, 11),
                   (12, 13), (13, 14), (14, 15),
                   (16, 17), (17, 18), (18, 19)]
length_vals = [0.5002, 0.4310,
               0.5772, 0.4574, 0.7900,
               0.5772, 0.4574, 0.7900,
               0.4095, 0.4395, 0.4415,
               0.4095, 0.4395, 0.4415]
weights = [0.0694, 0.4346,
           0.0271, 0.0162, 0.0061,
           0.0271, 0.0162, 0.0061,
           0.1416, 0.0433, 0.0137,
           0.1416, 0.0433, 0.0137]

filename = "locations.csv"

# %%
names = ['Segments', 'X','Y']

# %%
df = pd.read_csv(filename,names = names).copy()
df
# Out:
#        Segments    X    Y
# 0   Top_of_Head  104   25
# 1            C7  104   55
# 2          MidS  106   63
# 3          MidH  116  119
# 4    R_Shoulder  125   64
# 5       R_Elbow  147   65
# 6       R_Wrist  157   58
# 7     R_Fingers  153   41
# 8    L_Shoulder   86   62
# 9       L_Elbow   59   63
# 10      L_Wrist   25   57
# 11    L_Fingers   21   43
# 12        R_Hip  130  113
# 13       R_Knee  147   88
# 14      R_Ankle  168   73
# 15        R_Toe  164   55
# 16        L_Hip  106  123
# 17       L_Knee  109  167
# 18      L_Ankle  119  211
# 19        L_Toe  107  210

# %%
segment_names = ["Head_and_Neck", "Trunk", 
                 "R_Upper_Arm", "R_Forearm", "R_Hand", 
                 "L_Upper_Arm", "L_Forearm", "L_Hand",
                 "R_Thigh", "R_Shank", "R_Foot",
                 "L_Thigh", "L_Shank", "L_Foot"]

prox_dist_pairs = [(0, 1), (2, 3),
                   (4, 5), (5, 6), (6, 7),
                   (8, 9), (9, 10), (10, 11),
                   (12, 13), (13, 14), (14, 15),
                   (16, 17), (17, 18), (18, 19)]

length_vals = [0.5002, 0.4310,
               0.5772, 0.4574, 0.7900,
               0.5772, 0.4574, 0.7900,
               0.4095, 0.4395, 0.4415,
               0.4095, 0.4395, 0.4415]
weights = [0.0694, 0.4346,
           0.0271, 0.0162, 0.0061,
           0.0271, 0.0162, 0.0061,
           0.1416, 0.0433, 0.0137,
           0.1416, 0.0433, 0.0137]

# %%
names = ['segment name', 'proximal name', 'distal name', 'segment CoM x', 'segment CoM y']

var1, var2, var3, var4, var5 = [], [],[],[],[]

var0 = segment_names
var5 = weights
for i in range(len(length_vals)):
    pro_id = prox_dist_pairs[i][0]
    dis_id = prox_dist_pairs[i][1]
    ##print(pro_id)
    var1 = var1 + [df.iloc[int(pro_id),0]]
    var2 = var2 + [df.iloc[int(dis_id),0]]
    var3 = var3 + [int(np.around((1.0-length_vals[i])*df.iloc[pro_id,1] + length_vals[i]*df.iloc[dis_id,1]))]
    var4 = var4 + [int(np.around((1.0-length_vals[i])*df.iloc[pro_id,2] + length_vals[i]*df.iloc[dis_id,2]))]

    
data = {}
t = [var0,var1,var2,var3,var4]
for i in range(len(t)):
    data[names[i]] = t[i]

data
# Out:
# {'segment name': ['Head_and_Neck',
#   'Trunk',
#   'R_Upper_Arm',
#   'R_Forearm',
#   'R_Hand',
#   'L_Upper_Arm',
#   'L_Forearm',
#   'L_Hand',
#   'R_Thigh',
#   'R_Shank',
#   'R_Foot',
#   'L_Thigh',
#   'L_Shank',
#   'L_Foot'],
#  'proximal name': ['Top_of_Head',
#   'MidS',
#   'R_Shoulder',
#   'R_Elbow',
#   'R_Wrist',
#   'L_Shoulder',
#   'L_Elbow',
#   'L_Wrist',
#   'R_Hip',
#   'R_Knee',
#   'R_Ankle',
#   'L_Hip',
#   'L_Knee',
#   'L_Ankle'],
#  'distal name': ['C7',
#   'MidH',
#   'R_Elbow',
#   'R_Wrist',
#   'R_Fingers',
#   'L_Elbow',
#   'L_Wrist',
#   'L_Fingers',
#   'R_Knee',
#   'R_Ankle',
#   'R_Toe',
#   'L_Knee',
#   'L_Ankle',
#   'L_Toe'],
#  'segment CoM x': [104,
#   110,
#   138,
#   152,
#   154,
#   70,
#   43,
#   22,
#   137,
#   156,
#   166,
#   107,
#   113,
#   114],
#  'segment CoM y': [40, 87, 65, 62, 45, 63, 60, 46, 103, 81, 65, 141, 186, 211]}

# %%
df_output = pd.DataFrame(data)

df_output
# Out:
#      segment name proximal name distal name  segment CoM x  segment CoM y
# 0   Head_and_Neck   Top_of_Head          C7            104             40
# 1           Trunk          MidS        MidH            110             87
# 2     R_Upper_Arm    R_Shoulder     R_Elbow            138             65
# 3       R_Forearm       R_Elbow     R_Wrist            152             62
# 4          R_Hand       R_Wrist   R_Fingers            154             45
# 5     L_Upper_Arm    L_Shoulder     L_Elbow             70             63
# 6       L_Forearm       L_Elbow     L_Wrist             43             60
# 7          L_Hand       L_Wrist   L_Fingers             22             46
# 8         R_Thigh         R_Hip      R_Knee            137            103
# 9         R_Shank        R_Knee     R_Ankle            156             81
# 10         R_Foot       R_Ankle       R_Toe            166             65
# 11        L_Thigh         L_Hip      L_Knee            107            141
# 12        L_Shank        L_Knee     L_Ankle            113            186
# 13         L_Foot       L_Ankle       L_Toe            114            211

# %%
print("Output: segment name, proximal name, distal name, segment CoM x, segment CoM y")
for i in range(len(df_output['segment name'])):
    
    print(f"{df_output['segment name'][i]}, {df_output['proximal name'][i]}, {df_output['distal name'][i]}, {df_output['segment CoM x'][i]}, {df_output['segment CoM y'][i]}")
# Out:
# Output: segment name, proximal name, distal name, segment CoM x, segment CoM y
# Head_and_Neck, Top_of_Head, C7, 104, 40
# Trunk, MidS, MidH, 110, 87
# R_Upper_Arm, R_Shoulder, R_Elbow, 138, 65
# R_Forearm, R_Elbow, R_Wrist, 152, 62
# R_Hand, R_Wrist, R_Fingers, 154, 45
# L_Upper_Arm, L_Shoulder, L_Elbow, 70, 63
# L_Forearm, L_Elbow, L_Wrist, 43, 60
# L_Hand, L_Wrist, L_Fingers, 22, 46
# R_Thigh, R_Hip, R_Knee, 137, 103
# R_Shank, R_Knee, R_Ankle, 156, 81
# R_Foot, R_Ankle, R_Toe, 166, 65
# L_Thigh, L_Hip, L_Knee, 107, 141
# L_Shank, L_Knee, L_Ankle, 113, 186
# L_Foot, L_Ankle, L_Toe, 114, 211

# %%
com_x = 0.0
com_y = 0.0
for i in range(len(var5)):
    com_x += df_output['segment CoM x'][i] * var5[i]
    com_y += df_output['segment CoM y'][i] * var5[i]
print(f'Overall Center of Mass: ({int(np.around(com_x))}, {int(np.around(com_y))})')
# Out:
# Overall Center of Mass: (115, 96)
